# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xrange = np.linspace(0., 1., 101)
plt.plot(xrange, np.power(xrange, 2.))
plt.show()

# %%
plt.scatter(np.random.random(17), np.random.random(17), c=np.random.random(17))
plt.show()
