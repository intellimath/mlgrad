# %%
import sklearn.datasets as datasets
import matplotlib.pyplot as plt
import numpy as np

# %%
X, Y = datasets.load_iris(return_X_y=True)

# %%
import sklearn.decomposition as decomposition
import sklearn.preprocessing as preprocessing
from sklearn.metrics import accuracy_score

# %%
def calc_zz(mod, xr, yr):
    xrange = np.linspace(xr[0], xr[1], 101)
    yrange = np.linspace(yr[0], yr[1], 101)
    XX, YY = np.meshgrid(xrange, yrange)
    XY = np.c_[XX.ravel(), YY.ravel()]
    ZZ = mod.evaluate_all(XY)
    ZZ = ZZ.reshape(XX.shape)
    return ZZ

# %%
def plot_params(mod, ax=None):
    if ax is None:
        ax = plt.gca()
    ymax = np.asarray(mod.param.base[1:].copy())
    ymin = np.asarray(mod.param.base[1:].copy())
    np.putmask(ymax, ymax<0, 0)
    np.putmask(ymin, ymax>0, 0)
    n = len(ymin)
    print(n)
    ax.vlines(range(n), ymin, ymax, color='k', linewidth=1., label=r"Вектор коэффициентов $\mathbf{w}$")
    ax.minorticks_on()
    ax.set_ylabel(r"$w_k$")
    ax.legend(loc="upper right")

# %%
pca = decomposition.PCA()
pca.fit(X)
# Out:
# PCA()

# %%
plt.bar(range(4), pca.explained_variance_ratio_)
plt.show()

# %%
U = pca.transform(X)
U = U[:,:2]

# %%
U2 = U[Y != 0]
Y2 = Y[Y != 0]
np.putmask(Y2, Y2 == 1, -1)
np.putmask(Y2, Y2 == 2, +1)
Y2 = Y2.astype('d')

# %%
plt.figure(figsize=(10,6))
sc = plt.scatter(U2[:,0], U2[:,1], c=Y2)
plt.colorbar(sc,ticks=[-1,+1])
plt.minorticks_on()
plt.show()

# %%
import mlgrad.loss as loss
import mlgrad.funcs as funcs
import mlgrad.models as models
import mlgrad.funcs2 as funcs2
import mlgrad.gd as gd
import mlgrad.regr as regr
import mlgrad.plots as plots

# %%
hinge_loss = loss.MarginLoss(funcs.Hinge(0))
l2_reg = funcs2.SquareNorm()
l1_reg = funcs2.AbsoluteNorm()
sigmoidal_func = funcs.Sigmoidal(2.0)
sq_loss = loss.ErrorLoss(funcs.Square())

# %%
mod = models.SigmaNeuronModel(funcs.Sigmoidal(2.0), 2)

# %%
alg = regr.regression(U2, Y2, mod, 
                        loss_func=sq_loss, 
                        # lossfunc=hinge_loss, 
                        h=0.01, n_iter=1000)
print("Accuracy score:", accuracy_score(np.sign(mod.evaluate_all(U2)), Y2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 alg = regr.regression(U2, Y2, mod,
#       2                         loss_func=sq_loss,
#       3                         # lossfunc=hinge_loss,
#       4                         h=0.01, n_iter=1000)
#       5 print("Accuracy score:", accuracy_score(np.sign(mod.evaluate_all(U2)), Y2))
#
# File ~/.local/lib/python3.13/site-packages/mlgrad-0.7.4-py3.13-linux-x86_64.egg/mlgrad/regr/__init__.py:72, in regression(Xs, Y, mod, loss_func, regnorm, weights, normalizer, h, tol, n_iter, tau, verbose, n_restart, init_param)
#      69 if weights is not None:
#      70     er.use_weights(weights)
# ---> 72 alg = erm_fg(er, h=h, tol=tol, n_iter=n_iter,
#      73              verbose=verbose, n_restart=n_restart, normalizer=normalizer)
#      74 return alg
#
# File ~/.local/lib/python3.13/site-packages/mlgrad-0.7.4-py3.13-linux-x86_64.egg/mlgrad/__init__.py:104, in erm_fg(er, h, tol, n_iter, averager, callback, n_restart, verbose, normalizer)
#     100 alg = fg(er, h=h, tol=tol, n_iter=n_iter,
#     101          averager=averager, callback=callback,
#     102          normalizer=normalizer)
#     103 for i in range(n_restart):
# --> 104     alg.fit()
#     105     if verbose:
#     106         print("K={} param={}".format(alg.K, np.asarray(er.param)))
#
# File lib/mlgrad/gd.pyx:103, in mlgrad.gd.GD.fit()
#
# File lib/mlgrad/gd.pyx:68, in mlgrad.gd.GD.init()
#
# AttributeError: 'NoneType' object has no attribute 'n_param'

# %%
plots.plot_losses(alg)

# %%
plt.figure(figsize=(12,5))
plots.plot_cls_function(mod, U2, Y2)
plt.show()

# %%
ZZ = calc_zz(mod, [-1.,4.], [-1.5,1.5])
plt.figure(figsize=(12,7))
cs = plt.scatter(U2[:,0], U2[:,1], c=Y2, edgecolors='k', s=25)
plt.imshow(ZZ, origin='lower', extent=(-1., 4,-1.5, 1.5), alpha=0.75)
# plt.colorbar(cs, ticks=[-1,0,1])
plt.contour(ZZ, levels=[0], origin='lower', extent=(-1.,4,-1.5, 1.5), linewidths=1, colors='k')
# plt.contour(ZZ, levels=[-0.1,0.1], origin='lower', extent=(-1.,4,-1.5, 1.5), linewidths=0.5, linestyles='--')
# plt.xlim(-2,2)
# plt.ylim(-2,2)
plt.show()

# %%
def create_model(n_input, n_hidden):
    mod = models.LinearFuncModel()
    for i in range(n_hidden):
        mod.add(models.SigmaNeuronModel(funcs.Sigmoidal(6.0), n_input))
    return mod
nmod = create_model(2, 20)
print(nmod.weights.asarray())

# %%
nmod.init_param()

# %%
alg = regr.regression(U2, Y2, nmod,
                             loss_func=hinge_loss,
                             # lossfunc=sq_loss,
                             # regnorm=l1_reg, tau=0.001,
                             # normalizer=gd.Masked(nmod.n_param, 1.0e-5),
                             h=0.01)
accuracy_score(Y2, np.sign(nmod.evaluate(U2)))

# %%
plt.plot(alg.lvals)
plt.show()

# %%
plt.figure(figsize=(12,5))
plots.plot_cls_function(nnmod, U2, Y2)
plt.show()

# %%
ZZ = calc_zz(nnmod, [-1.,4.], [-1.5,1.5])
plt.figure(figsize=(12,7))
cs = plt.scatter(U2[:,0], U2[:,1], c=Y2, edgecolors='k', s=25)
# plt.imshow(ZZ, origin='lower', extent=(-1., 4,-1.5, 1.5), alpha=0.75)
# plt.colorbar(cs, ticks=[-1,0,1])
plt.contour(ZZ, levels=[0], origin='lower', extent=(-1.,4,-1.5, 1.5), linewidths=1, colors='k')
# plt.contour(ZZ, levels=[-1,1], origin='lower', extent=(-1.,4,-1.5, 1.5), linewidths=0.5, linestyles='--')
# plt.xlim(-2,2)
# plt.ylim(-2,2)
plt.show()

# %%
plt.figure(figsize=(20,4))
plot_params(nnmod)
plt.vlines([n_hidden+(U2.shape[1]+1)*i for i in range(n_hidden)], 0, 2)
plt.show()
# Out:
# 80

# %%
plt.figure(figsize=(20,4))
plot_params(nnmod)
plt.vlines([n_hidden+(U2.shape[1]+1)*i for i in range(n_hidden)], 0, 2)
plt.show()
# Out:
# 80
