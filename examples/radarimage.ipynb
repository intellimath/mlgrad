# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sklearn.preprocessing as preprocessing

# %%
df = pd.read_csv("data/radarimage.csv", index_col="rownames")
df
# Out:
#           X.coord  Y.coord   Band.1   Band.2   Band.3
# rownames
# 1              59        1   157.20  -150.50   30.020
# 2              60        1    52.12   -72.61   -6.376
# 3              61        1  -188.10   -82.81  -55.630
# 4              62        1   -17.10    10.09  -21.230
# 5              52        2    18.39   -22.43   86.390
# ...           ...      ...      ...      ...      ...
# 1569           68       29 -1381.00   388.70  -90.370
# 1570           69       29 -4702.00  -729.40 -306.000
# 1571           70       29 -3293.00 -1610.00 -119.500
# 1572           68       30  -105.30  -103.30  -57.320
# 1573           69       30  -457.80  -513.50 -197.700
#
# [1573 rows x 5 columns]

# %%
X = df["X.coord"].values
Y = df["Y.coord"].values
B1 = df["Band.1"].values
B2 = df["Band.2"].values
B3 = df["Band.3"].values

# %%
B1 = preprocessing.robust_scale(B1)
B2 = preprocessing.robust_scale(B2)
B3 = preprocessing.robust_scale(B3)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.scatter(X, B1, s=9, c='w', edgecolors='r', label='B1')
plt.scatter(X, B2, s=9, c='w', edgecolors='g', label='B2')
plt.scatter(X, B3, s=9, c='w', edgecolors='b', label='B3')
plt.legend()
plt.subplot(1,2,2)
plt.scatter(Y, B1, s=9, c='w', edgecolors='r', label='B1')
plt.scatter(Y, B2, s=9, c='w', edgecolors='g', label='B2')
plt.scatter(Y, B3, s=9, c='w', edgecolors='b', label='B3')
plt.legend()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(X, Y, B1, s=9, c='w', edgecolors='r', label='B1')
# ax.scatter(X, Y, B2, s=9, c='w', edgecolors='g', label='B2')
# ax.scatter(X, Y, B3, s=9, c='w', edgecolors='b', label='B3')
plt.legend()
plt.show()
