# %%
import numpy as np
import matplotlib.pyplot as plt
import mlgrad.af as af
import mlgrad.funcs as funcs
import mlgrad.utils as utils
import mlgrad.pca as pca
import mlgrad.plots as plots
import pandas as pd
import sklearn.datasets as datasets

# %%
X, Y = datasets.load_iris(return_X_y=True)

# %%
X0 = X
Y0 = Y
c = pca.location(X0)
print(c)
# Out:
# [5.843 3.057 3.758 1.199]

# %%
Ls,As,Us = pca.find_pc_all(X0-c, 3, verbose=True)
print(Ls)
print(As)
# Out:
# K: 6 4.200053427993636 [ 0.361 -0.085  0.857  0.358]
# K: 11 0.2410529429417102 [ 0.657  0.730 -0.173 -0.075]
# K: 12 0.07768810337595289 [-0.582  0.598  0.076  0.546]
# [[ 0.361 -0.085  0.857  0.358]
#  [ 0.657  0.730 -0.173 -0.075]
#  [-0.582  0.598  0.076  0.546]]
# [4.200 0.241 0.078]

# %%
plt.scatter(Us[0], Us[1], c=Y0, edgecolors='k', s=25)
plt.show()

# %%
c1 = pca.location_l1(X0, verbose=True)
# Out:
# 1.9440683605553901 [5.843 3.057 3.758 1.199]
# * 1.9018478849363107 [5.849 2.927 3.990 1.276]
# * 1.8922792997937234 [5.874 2.903 4.100 1.313]
# * 1.8898036307406476 [5.893 2.903 4.152 1.334]
# * 1.8890128616023008 [5.907 2.906 4.179 1.347]
# * 1.8887353582084359 [5.917 2.909 4.194 1.354]
# * 1.8886354831452912 [5.923 2.910 4.203 1.358]
# * 1.8885992761085306 [5.927 2.911 4.208 1.361]
# * 1.8885861113542581 [5.929 2.912 4.211 1.362]
# * 1.8885813172093833 [5.930 2.912 4.213 1.363]
# * 1.8885795697583445 [5.931 2.912 4.214 1.364]
# * 1.888578932470194 [5.931 2.912 4.215 1.364]
# * 1.888578699977298 [5.932 2.912 4.215 1.364]
# * 1.8885786151432902 [5.932 2.912 4.215 1.365]
# * 1.888578584184602 [5.932 2.912 4.216 1.365]
# * 1.8885785728859477 [5.932 2.912 4.216 1.365]
# * 1.8885785687622199 [5.932 2.912 4.216 1.365]
# * 1.8885785672571216 [5.932 2.912 4.216 1.365]
# K: 16 1.8885785672571216 [5.932 2.912 4.216 1.365]

# %%
Ls1, As1, Us1 = pca.find_pc_l1_all(X0-c1, 3, verbose=True)
print(Ls1)
print(As1)
# Out:
# *** 0 ***
# K: 7 1.7562351388375557 [0.421 0.022 0.833 0.359]
# * 0.5815306315358457 1.7562351388381212 [0.522 0.469 0.658 0.272]
# K: 5 3.6890470618501436 [ 0.385 -0.051  0.849  0.358]
# * 0.536102245084528 3.689047061850249 [0.421 0.022 0.833 0.359]
# K: 4 4.486554552547623 [ 0.367 -0.075  0.855  0.360]
# * 0.5281788451520788 4.486554552549537 [ 0.385 -0.051  0.849  0.358]
# K: 4 4.673840875253467 [ 0.358 -0.084  0.857  0.360]
# * 0.5265782708816586 4.67384087525371 [ 0.367 -0.075  0.855  0.360]
# K: 4 4.650125000244049 [ 0.354 -0.088  0.859  0.360]
# * 0.5261944622300462 4.650125000244108 [ 0.358 -0.084  0.857  0.360]
# K: 4 4.600432299268414 [ 0.351 -0.091  0.860  0.360]
# * 0.5260881889779955 4.600432299268434 [ 0.354 -0.088  0.859  0.360]
# K: 3 4.568339285273008 [ 0.350 -0.092  0.860  0.360]
# * 0.5260557879385832 4.5683392852812785 [ 0.351 -0.091  0.860  0.360]
# K: 3 4.550717729775888 [ 0.349 -0.093  0.860  0.360]
# * 0.5260454938992809 4.550717729778583 [ 0.350 -0.092  0.860  0.360]
# K: 3 4.541118957431878 [ 0.349 -0.093  0.860  0.360]
# * 0.5260421591577983 4.5411189574327615 [ 0.349 -0.093  0.860  0.360]
# K: 3 4.5358073967833805 [ 0.349 -0.093  0.860  0.360]
# * 0.526041067479725 4.535807396783671 [ 0.349 -0.093  0.860  0.360]
# K: 10 0.526041067479725 [ 0.349 -0.093  0.860  0.360] 4.535807396783671
# *** 1 ***
# K: 18 0.1175182926363493 [ 0.652  0.736 -0.181 -0.008]
# * 0.2762017357322224 0.11751829263650605 [0.164 0.126 0.264 0.942]
# K: 6 0.2190303299534278 [ 0.655  0.736 -0.169 -0.041]
# * 0.2751921610606647 0.2190303299538496 [ 0.652  0.736 -0.181 -0.008]
# K: 6 0.22641436289391803 [ 0.659  0.732 -0.166 -0.052]
# * 0.27503065776952484 0.22641436289398598 [ 0.655  0.736 -0.169 -0.041]
# K: 6 0.23000749438075016 [ 0.662  0.728 -0.166 -0.057]
# * 0.27498196185288976 0.23000749438076923 [ 0.659  0.732 -0.166 -0.052]
# K: 5 0.23199788130194599 [ 0.665  0.726 -0.166 -0.059]
# * 0.2749598027947345 0.23199788130233676 [ 0.662  0.728 -0.166 -0.057]
# K: 5 0.23327448848950508 [ 0.667  0.724 -0.166 -0.061]
# * 0.27494852289334726 0.23327448848967006 [ 0.665  0.726 -0.166 -0.059]
# K: 5 0.2341772704384969 [ 0.669  0.722 -0.167 -0.061]
# * 0.2749427819263258 0.23417727043856998 [ 0.667  0.724 -0.166 -0.061]
# K: 5 0.23484191661757078 [ 0.670  0.721 -0.167 -0.062]
# * 0.2749399303764873 0.23484191661760376 [ 0.669  0.722 -0.167 -0.061]
# K: 5 0.23533445752924115 [ 0.670  0.720 -0.167 -0.062]
# * 0.27493854802084233 0.23533445752925614 [ 0.670  0.721 -0.167 -0.062]
# K: 4 0.23569647013653913 [ 0.671  0.720 -0.168 -0.063]
# * 0.2749378906389328 0.23569647013697212 [ 0.670  0.720 -0.167 -0.062]
# K: 10 0.2749378906389328 [ 0.671  0.720 -0.168 -0.063] 0.23569647013697212
# *** 2 ***
# K: 12 0.032907278045390745 [-0.588  0.614  0.088  0.519]
# * 0.11732037773372321 0.03290727804540014 [0.138 0.785 0.248 0.550]
# K: 2 0.1040899710930491 [-0.588  0.614  0.088  0.519]
# * 0.11732035453647477 0.10408997109304907 [-0.588  0.614  0.088  0.519]
# K: 2 0.11732035453647477 [-0.588  0.614  0.088  0.519] 0.10408997109304907
# [[ 0.349 -0.093  0.860  0.360]
#  [ 0.671  0.720 -0.168 -0.063]
#  [-0.588  0.614  0.088  0.519]]
# [4.536 0.236 0.104]

# %%
# print(Us)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1,2,1)
plt.scatter(Us[0], Us[1], c=Y0, edgecolors='k', s=25)
plt.minorticks_on()
plt.subplot(1,2,2)
plt.scatter(Us1[0], Us1[1], c=Y0, edgecolors='k', s=25)
plt.minorticks_on()
plt.tight_layout()
plt.show()
