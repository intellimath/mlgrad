# %%
import numpy as np
import mlgrad.func as func
from mlgrad import average_it

import matplotlib.pyplot as plt

# %%
X = np.random.random((100,))

# %%
vs = []
ks = []
alphas = np.linspace(0.05, 0.95, 100)
m = len(alphas)
for alpha in alphas:
    #X = np.ones(1000, 'd')
    X = np.random.random((1000,))    
    M = int(100 * alpha)-1
    X[-M:-1] = 100
    f = func.Quantile_Sqrt(0.001, alpha)
    alg = average_it(X, f)
    ks.append(alg.K)
    vs.append(alg.u)

# %%
plt.figure(figsize=(9,3))
plt.subplot(1, 2, 1)
plt.plot(alphas, vs, label='u')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(alphas, ks, label='K')
plt.legend()
plt.tight_layout()
plt.show()

# %%
vs = []
ks = []
alphas = np.linspace(0.05, 0.95, 200)
m = len(alphas)
for alpha in alphas:
    X = np.random.random((1000,))    
    M = int(100 * alpha)-1
    X[-M:-1] = 100
    f = func.Expectile(alpha)
    alg = average_it(X, f)
    ks.append(alg.K)
    vs.append(alg.u)

# %%
plt.figure(figsize=(9,3))
plt.subplot(1, 2, 1)
plt.plot(alphas, vs, label='u')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(alphas, ks, label='K')
plt.legend()
plt.tight_layout()
plt.show()
