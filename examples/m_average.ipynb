# %%
import mlgrad.func as func
import mlgrad.avragg as avragg
import matplotlib.pyplot as plt
import numpy as np

from mlgrad import averager_it, average_it

# %%
X = 10*np.random.random((1000,))

# %%
alphas = np.linspace(0.01, 0.99, 21)
ks = []
vs = []
for alpha in alphas:
    print(alpha)
    agg = averager_it(func.Quantile_Sqrt(alpha, 0.001))
    agg.fit(X)
    agg.nabla(X)
    ks.append(agg.K)
    vs.append(agg.u)
# Out:
# 0.01
# 0.059000000000000004
# 0.108
# 0.15700000000000003
# 0.20600000000000002
# 0.255
# 0.30400000000000005
# 0.35300000000000004
# 0.402
# 0.451
# 0.5
# 0.549
# 0.5980000000000001
# 0.647
# 0.6960000000000001
# 0.745
# 0.794
# 0.8430000000000001
# 0.892
# 0.9410000000000001
# 0.99

# %%
plt.figure(figsize=(9,3))
plt.subplot(1, 2, 1)
plt.plot(alphas, vs, label='u')
plt.legend()
plt.minorticks_on()
plt.grid(1)
plt.subplot(1, 2, 2)
plt.plot(alphas, ks, label='K')
plt.legend()
plt.tight_layout()
plt.show()

# %%
alphas = np.linspace(0.01, 0.99, 20)
ks = []
vs = []
for alpha in alphas:
    agg = avragg.WMAverage(averager_it(func.Quantile_Sqrt(alpha, 0.001)))
    agg.fit(X)
    ks.append(agg.K)
    vs.append(agg.u)

# %%
plt.figure(figsize=(9,3))
plt.subplot(1, 2, 1)
plt.plot(alphas, vs, label='u')
plt.legend()
plt.minorticks_on()
plt.grid(1)
plt.subplot(1, 2, 2)
plt.plot(alphas, ks, label='K')
plt.legend()
plt.tight_layout()
plt.show()
