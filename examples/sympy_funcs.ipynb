# %%
import sympy as sym
from sympy.abc import x, y, z, t, a, b, c, d

# %%
f=(1/2)*(x-sym.sqrt(a**2+x**2)+a)

# %%
sym.diff(f, x)
# Out:
# -0.5*x/sqrt(a**2 + x**2) + 0.5

# %%
sym.plot(F.subs({"a":1}))

# %%
F=sym.integrate(f, x)
F
# Out:
# -0.25*a**2*asinh(x/a) - 0.25*a*x*sqrt(1 + x**2/a**2) + 0.5*a*x + 0.25*x**2

# %%
F.subs({"a":0.1})
# Out:
# 0.25*x**2 - 0.25*x*sqrt(x**2 + 0.01) + 0.05*x - 0.0025*asinh(10.0*x)

# %%
sym.plot(F.subs({"a":0.1}))

# %%
sym.plot(f.subs({"a":0.1})/x)
